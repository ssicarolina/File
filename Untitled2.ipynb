# %%
"""
plot fungsi sinus
Syahril Siregar
2018/2/14
"""
import numpy as np # Numpy - Numerical Python
import matplotlib.pyplot as plt
t = np.linspace(-3*np.pi, 3*np.pi, 100)
y = np.sin(t)
plt.plot(t/np.pi,y) #-> Plot garis
plt.show()
