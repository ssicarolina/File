# %%
#                           PERSAMAAN DIFERENSIAL PARSIAL
#                               8.1 Persamaan Panas

"""         Contoh 
Jika suhu pada batang tersebut terisolasi dan
suhu pada kedua ujungnya dipertahankan 0, maka diperoleh syarat batas u(0,t) = u(L,t) = 0
untuk t > 0. Jika suhu batang saat awal konstan, u0, maka u(x, 0) = u0 untuk 0 < x < L.
Berikut ilustrasinya untuk L = 50, k = 1, dan u0 = 100. Permukaan dibuat dengan
mengambil 10 suku pertama solusi.
"""

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

# Domain pengamatan 
x = np.linspace(0,50,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

# Reset nilai U
U = 0
u0 = 100  # u(x,0)
k = 1
L = 50

# Hampiran solusi (10 solusi pertama)
for n in range(10):
    U = U + np.exp(-((2*n+1)*np.pi/L)**2*k*t)/(2* n+1)*np.sin((2* n+1)*np.pi*x/L)

U = 4*u0 / np.pi*U
surf=ax.plot_surface(x,t,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

plt.plot(U,t)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#                               8.1 Persamaan Gelombang

"""

"""

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

# Domain pengamatan 
x = np.linspace(0,50,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

# Reset nilai U
U = 0
u0 = 100            #u(x,0) = f(x) = sin(πx/L)
k = 1
L = 50
for n in range(10):
    U = U + np.cos(np.pi*t/L)*np.sin(np.pi*x/L)

U = 4*u0 / np.pi*U

surf=ax.plot_surface(x,t,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
# Nomor 1

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(0,100,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

U = 0

k = 4
L = 10
for n in range(10):
    u0 = np.cos(5*np.pi*x)
    U = U + np.exp(-4*t*pow(np.pi,2)/25)*u0

surf=ax.plot_surface(x,t,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
# Nomor 1

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(0,100,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

U = 0
u0 = np.cos(5*np.pi*x)
k = 4
L = 10

U = np.exp(-4*t*pow(np.pi,2)/25)*np.cos(5*np.pi*x)

surf=ax.plot_surface(x,t,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
# Nomor 2

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(0,10,250)
t = np.linspace(0,1,250)
x,t = np.meshgrid(x,t)

U = (np.sin(np.pi*(x-2*t)) + np.sin(np.pi*(x+2*t))) / 2
f1 = np.sin(np.pi - (x - 2*t))
f2 = np.sin(np.pi - (x + 2*t))

surf=ax.plot_surface(x,t,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
# Persamaan Laplace
len_sim = 5
for n in range (1,len_sim) : 
    int = integrate.quad(lambda d: sin(d)*sin(n*np.pi*d/b), 0, b)
    cn = (2/b)*int[0]/np.sinh(n* np.pi*a/b)
    print(n)
    print(np.sinh(n *np.pi*a/b))

    U = U + cn*np.sinh(n*np.pi*x/np.pi)*np.sin(n*np.pi*y/np.pi)

print(np.shape(U))
print(U)

# Visualisasi
surf = ax.plot_surface(x,y,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('Hampiran solusi (5 suku pertama)')
plt.show()
