# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML  # for embedded matplotlib animation

import inspect  #This allows us to print the source code in this notebook.
from RandomWalk import *  #Import the custom function from this project.

n = 50  # number of steps
data = np.array(RandomWalk(n))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-746f716b8cbc> in <module>()
#       5
#       6 import inspect  #This allows us to print the source code in this notebook.
# ----> 7 from RandomWalk import *  #Import the custom function from this project.
#       8
#       9 n = 50  # number of steps
#
# ModuleNotFoundError: No module named 'RandomWalk'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
