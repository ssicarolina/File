# %%
pip install datapackage
# Out:
# Collecting datapackage
#   Downloading datapackage-1.15.2-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 2.6 MB/s
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.7/dist-packages (from datapackage) (7.1.2)
# Requirement already satisfied: requests>=2.8 in /usr/local/lib/python3.7/dist-packages (from datapackage) (2.23.0)
# Collecting jsonpointer>=1.10
#   Downloading jsonpointer-2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: chardet>=3.0 in /usr/local/lib/python3.7/dist-packages (from datapackage) (3.0.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from datapackage) (1.15.0)
# Collecting unicodecsv>=0.14
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Collecting tableschema>=1.12.1
#   Downloading tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 5.5 MB/s
# Collecting tabulator>=1.29
#   Downloading tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 518 kB/s
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.7/dist-packages (from datapackage) (2.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8->datapackage) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8->datapackage) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8->datapackage) (2021.10.8)
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.7/dist-packages (from tableschema>=1.12.1->datapackage) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from tableschema>=1.12.1->datapackage) (2.8.2)
# Collecting rfc3986>=1.1.0
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.5 MB/s
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.29->datapackage) (1.4.27)
# Collecting linear-tsv>=1.0
#   Downloading linear-tsv-1.1.0.tar.gz (9.6 kB)
# Collecting jsonlines>=1.1
#   Downloading jsonlines-2.0.0-py3-none-any.whl (6.3 kB)
# Collecting openpyxl>=2.6
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 44.9 MB/s
# Collecting boto3>=1.9
#   Downloading boto3-1.20.14-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 56.7 MB/s
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.29->datapackage) (1.1.0)
# Collecting ijson>=3.0.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 59.7 MB/s
# Collecting botocore<1.24.0,>=1.23.14
#   Downloading botocore-1.23.14-py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 39.6 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.2 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 70.5 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6->tabulator>=1.29->datapackage) (1.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (4.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (1.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (3.10.0.2)
# Building wheels for collected packages: linear-tsv, unicodecsv
#   Building wheel for linear-tsv (setup.py) ... done
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7399 sha256=29a4f06d0a68c22d87d45aedcbdffd12347103567e6bbdc0c6e6e4d64ed64651
#   Stored in directory: /root/.cache/pip/wheels/dd/0a/62/49ee84fab92057fb3e303fb1a59e75ccac6899b417f441305a
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10765 sha256=1b234cb2df620879483ea4628855edd7da6d7265ff4e6b09ee4261f7b35c15ed
#   Stored in directory: /root/.cache/pip/wheels/1a/f4/8a/a5024fb77b32ed369e5c409081e5f00fbe3b92fdad653f6e69
# Successfully built linear-tsv unicodecsv
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, unicodecsv, openpyxl, linear-tsv, jsonlines, ijson, boto3, tabulator, rfc3986, isodate, tableschema, jsonpointer, datapackage
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.20.14 botocore-1.23.14 datapackage-1.15.2 ijson-3.1.4 isodate-0.6.0 jmespath-0.10.0 jsonlines-2.0.0 jsonpointer-2.2 linear-tsv-1.1.0 openpyxl-3.0.9 rfc3986-1.5.0 s3transfer-0.5.0 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 urllib3-1.25.11

# %%
from datapackage import Package

package = Package('https://datahub.io/core/global-temp/datapackage.json')

# print list of all resources:
print(package.resource_names)

# print processed tabular data (if exists any)
for resource in package.resources:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        print(resource.read())
# Out:
# ['validation_report', 'annual_csv', 'monthly_csv', 'annual_json', 'monthly_json', 'global-temp_zip', 'monthly_csv_preview', 'annual', 'monthly']
# [['GCAG', 2016, Decimal('0.9363')], ['GISTEMP', 2016, Decimal('0.99')], ['GCAG', 2015, Decimal('0.8998')], ['GISTEMP', 2015, Decimal('0.87')], ['GCAG', 2014, Decimal('0.7408')], ['GISTEMP', 2014, Decimal('0.74')], ['GCAG', 2013, Decimal('0.6679')], ['GISTEMP', 2013, Decimal('0.65')], ['GCAG', 2012, Decimal('0.6240')], ['GISTEMP', 2012, Decimal('0.63')], ['GCAG', 2011, Decimal('0.5788')], ['GISTEMP', 2011, Decimal('0.6')], ['GCAG', 2010, Decimal('0.7014')], ['GISTEMP', 2010, Decimal('0.71')], ['GCAG', 2009, Decimal('0.6367')], ['GISTEMP', 2009, Decimal('0.64')], ['GCAG', 2008, Decimal('0.5419')], ['GISTEMP', 2008, Decimal('0.54')], ['GCAG', 2007, Decimal('0.6100')], ['GISTEMP', 2007, Decimal('0.66')], ['GCAG', 2006, Decimal('0.6125')], ['GISTEMP', 2006, Decimal('0.63')], ['GCAG', 2005, Decimal('0.6585')], ['GISTEMP', 2005, Decimal('0.69')], ['GCAG', 2004, Decimal('0.5783')], ['GISTEMP', 2004, Decimal('0.55')], ['GCAG', 2003, Decimal('0.6134')], ['GISTEMP', 2003, Decimal('0.62')], ['GCAG', 2002, Decimal('0.6023')], ['GISTEMP', 2002, Decimal('0.63')], ['GCAG', 2001, Decimal('0.5473')], ['GISTEMP', 2001, Decimal('0.55')], ['GCAG', 2000, Decimal('0.4262')], ['GISTEMP', 2000, Decimal('0.42')], ['GCAG', 1999, Decimal('0.4438')], ['GISTEMP', 1999, Decimal('0.42')], ['GCAG', 1998, Decimal('0.6344')], ['GISTEMP', 1998, Decimal('0.64')], ['GCAG', 1997, Decimal('0.5187')], ['GISTEMP', 1997, Decimal('0.48')], ['GCAG', 1996, Decimal('0.3228')], ['GISTEMP', 1996, Decimal('0.35')], ['GCAG', 1995, Decimal('0.4577')], ['GISTEMP', 1995, Decimal('0.46')], ['GCAG', 1994, Decimal('0.3409')], ['GISTEMP', 1994, Decimal('0.32')], ['GCAG', 1993, Decimal('0.2853')], ['GISTEMP', 1993, Decimal('0.24')], ['GCAG', 1992, Decimal('0.2571')], ['GISTEMP', 1992, Decimal('0.23')], ['GCAG', 1991, Decimal('0.4055')], ['GISTEMP', 1991, Decimal('0.43')], ['GCAG', 1990, Decimal('0.4328')], ['GISTEMP', 1990, Decimal('0.44')], ['GCAG', 1989, Decimal('0.2970')], ['GISTEMP', 1989, Decimal('0.29')], ['GCAG', 1988, Decimal('0.3757')], ['GISTEMP', 1988, Decimal('0.41')], ['GCAG', 1987, Decimal('0.3696')], ['GISTEMP', 1987, Decimal('0.33')], ['GCAG', 1986, Decimal('0.2296')], ['GISTEMP', 1986, Decimal('0.19')], ['GCAG', 1985, Decimal('0.1342')], ['GISTEMP', 1985, Decimal('0.12')], ['GCAG', 1984, Decimal('0.1490')], ['GISTEMP', 1984, Decimal('0.15')], ['GCAG', 1983, Decimal('0.3411')], ['GISTEMP', 1983, Decimal('0.3')], ['GCAG', 1982, Decimal('0.1815')], ['GISTEMP', 1982, Decimal('0.13')], ['GCAG', 1981, Decimal('0.2999')], ['GISTEMP', 1981, Decimal('0.33')], ['GCAG', 1980, Decimal('0.2637')], ['GISTEMP', 1980, Decimal('0.27')], ['GCAG', 1979, Decimal('0.2273')], ['GISTEMP', 1979, Decimal('0.17')], ['GCAG', 1978, Decimal('0.1123')], ['GISTEMP', 1978, Decimal('0.07')], ['GCAG', 1977, Decimal('0.1978')], ['GISTEMP', 1977, Decimal('0.18')], ['GCAG', 1976, Decimal('-0.0792')], ['GISTEMP', 1976, Decimal('-0.11')], ['GCAG', 1975, Decimal('0.0034')], ['GISTEMP', 1975, Decimal('-0.02')], ['GCAG', 1974, Decimal('-0.0719')], ['GISTEMP', 1974, Decimal('-0.07')], ['GCAG', 1973, Decimal('0.1641')], ['GISTEMP', 1973, Decimal('0.15')], ['GCAG', 1972, Decimal('0.0264')], ['GISTEMP', 1972, Decimal('0.01')], ['GCAG', 1971, Decimal('-0.0783')], ['GISTEMP', 1971, Decimal('-0.09')], ['GCAG', 1970, Decimal('0.0372')], ['GISTEMP', 1970, Decimal('0.02')], ['GCAG', 1969, Decimal('0.0929')], ['GISTEMP', 1969, Decimal('0.07')], ['GCAG', 1968, Decimal('-0.0296')], ['GISTEMP', 1968, Decimal('-0.07')], ['GCAG', 1967, Decimal('-0.0131')], ['GISTEMP', 1967, Decimal('-0.02')], ['GCAG', 1966, Decimal('-0.0227')], ['GISTEMP', 1966, Decimal('-0.05')], ['GCAG', 1965, Decimal('-0.0780')], ['GISTEMP', 1965, Decimal('-0.1')], ['GCAG', 1964, Decimal('-0.1495')], ['GISTEMP', 1964, Decimal('-0.2')], ['GCAG', 1963, Decimal('0.1068')], ['GISTEMP', 1963, Decimal('0.06')], ['GCAG', 1962, Decimal('0.0888')], ['GISTEMP', 1962, Decimal('0.03')], ['GCAG', 1961, Decimal('0.0775')], ['GISTEMP', 1961, Decimal('0.05')], ['GCAG', 1 ...
# [['GCAG', datetime.date(2016, 12, 6), Decimal('0.7895')], ['GISTEMP', datetime.date(2016, 12, 6), Decimal('0.81')], ['GCAG', datetime.date(2016, 11, 6), Decimal('0.7504')], ['GISTEMP', datetime.date(2016, 11, 6), Decimal('0.93')], ['GCAG', datetime.date(2016, 10, 6), Decimal('0.7292')], ['GISTEMP', datetime.date(2016, 10, 6), Decimal('0.89')], ['GCAG', datetime.date(2016, 9, 6), Decimal('0.8767')], ['GISTEMP', datetime.date(2016, 9, 6), Decimal('0.87')], ['GCAG', datetime.date(2016, 8, 6), Decimal('0.8998')], ['GISTEMP', datetime.date(2016, 8, 6), Decimal('0.98')], ['GCAG', datetime.date(2016, 7, 6), Decimal('0.8687')], ['GISTEMP', datetime.date(2016, 7, 6), Decimal('0.83')], ['GCAG', datetime.date(2016, 6, 6), Decimal('0.9006')], ['GISTEMP', datetime.date(2016, 6, 6), Decimal('0.76')], ['GCAG', datetime.date(2016, 5, 6), Decimal('0.8738')], ['GISTEMP', datetime.date(2016, 5, 6), Decimal('0.93')], ['GCAG', datetime.date(2016, 4, 6), Decimal('1.0733')], ['GISTEMP', datetime.date(2016, 4, 6), Decimal('1.09')], ['GCAG', datetime.date(2016, 3, 6), Decimal('1.2245')], ['GISTEMP', datetime.date(2016, 3, 6), Decimal('1.3')], ['GCAG', datetime.date(2016, 2, 6), Decimal('1.1921')], ['GISTEMP', datetime.date(2016, 2, 6), Decimal('1.35')], ['GCAG', datetime.date(2016, 1, 6), Decimal('1.0569')], ['GISTEMP', datetime.date(2016, 1, 6), Decimal('1.17')], ['GCAG', datetime.date(2015, 12, 6), Decimal('1.1219')], ['GISTEMP', datetime.date(2015, 12, 6), Decimal('1.11')], ['GCAG', datetime.date(2015, 11, 6), Decimal('0.9655')], ['GISTEMP', datetime.date(2015, 11, 6), Decimal('1.04')], ['GCAG', datetime.date(2015, 10, 6), Decimal('0.9913')], ['GISTEMP', datetime.date(2015, 10, 6), Decimal('1.06')], ['GCAG', datetime.date(2015, 9, 6), Decimal('0.9260')], ['GISTEMP', datetime.date(2015, 9, 6), Decimal('0.81')], ['GCAG', datetime.date(2015, 8, 6), Decimal('0.8746')], ['GISTEMP', datetime.date(2015, 8, 6), Decimal('0.78')], ['GCAG', datetime.date(2015, 7, 6), Decimal('0.8072')], ['GISTEMP', datetime.date(2015, 7, 6), Decimal('0.71')], ['GCAG', datetime.date(2015, 6, 6), Decimal('0.8835')], ['GISTEMP', datetime.date(2015, 6, 6), Decimal('0.78')], ['GCAG', datetime.date(2015, 5, 6), Decimal('0.8584')], ['GISTEMP', datetime.date(2015, 5, 6), Decimal('0.78')], ['GCAG', datetime.date(2015, 4, 6), Decimal('0.7741')], ['GISTEMP', datetime.date(2015, 4, 6), Decimal('0.74')], ['GCAG', datetime.date(2015, 3, 6), Decimal('0.8969')], ['GISTEMP', datetime.date(2015, 3, 6), Decimal('0.9')], ['GCAG', datetime.date(2015, 2, 6), Decimal('0.8843')], ['GISTEMP', datetime.date(2015, 2, 6), Decimal('0.86')], ['GCAG', datetime.date(2015, 1, 6), Decimal('0.8141')], ['GISTEMP', datetime.date(2015, 1, 6), Decimal('0.81')], ['GCAG', datetime.date(2014, 12, 6), Decimal('0.8308')], ['GISTEMP', datetime.date(2014, 12, 6), Decimal('0.79')], ['GCAG', datetime.date(2014, 11, 6), Decimal('0.6895')], ['GISTEMP', datetime.date(2014, 11, 6), Decimal('0.67')], ['GCAG', datetime.date(2014, 10, 6), Decimal('0.7851')], ['GISTEMP', datetime.date(2014, 10, 6), Decimal('0.85')], ['GCAG', datetime.date(2014, 9, 6), Decimal('0.7872')], ['GISTEMP', datetime.date(2014, 9, 6), Decimal('0.9')], ['GCAG', datetime.date(2014, 8, 6), Decimal('0.7986')], ['GISTEMP', datetime.date(2014, 8, 6), Decimal('0.82')], ['GCAG', datetime.date(2014, 7, 6), Decimal('0.6988')], ['GISTEMP', datetime.date(2014, 7, 6), Decimal('0.57')], ['GCAG', datetime.date(2014, 6, 6), Decimal('0.7623')], ['GISTEMP', datetime.date(2014, 6, 6), Decimal('0.66')], ['GCAG', datetime.date(2014, 5, 6), Decimal('0.7938')], ['GISTEMP', datetime.date(2014, 5, 6), Decimal('0.87')], ['GCAG', datetime.date(2014, 4, 6), Decimal('0.8006')], ['GISTEMP', datetime.date(2014, 4, 6), Decimal('0.78')], ['GCAG', datetime.date(2014, 3, 6), Decimal('0.7695')], ['GISTEMP', datetime.date(2014, 3, 6), Decimal('0.77')], ['GCAG', datetime.date(2014, 2, 6), Decimal('0.4800')], ['GISTEMP', datetime.date(2014, 2, 6), Decimal('0.51')], ['GCAG', datetime.date(2014,  ...
