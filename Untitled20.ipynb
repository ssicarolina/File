# %%
# Mencari Solusi dari 2x'' + x' + 2x = DiracDelta(t-5)
from sympy.integrals.transforms import laplace_transform
from sympy.integrals.transforms import inverse_laplace_transform
from sympy import *
from sympy.abc import t, x, s, X, f, F
x, f, X = symbols('x f X', cls = Function)
t = symbols('t', positive = True)
s = symbols('s', real = True)
f = DiracDelta(t-5)
x0 = 0              # x(0) = 0
v0 = 0              # x'(0) = 0
#input hasil transformasi Laplace persamaan diferensial
eom = Eq(2*(s**2*X(s)-s*x0-v0) + (s*X(s)-x0) + 2*X(s), laplace_transform(f, t, s, noconds = True))
Xofs = solve(eom,X(s))
soln = inverse_laplace_transform(Xofs[0],s,t)
soln_simp = expand(soln)
soln_simp
# Out:
# 2*sqrt(15)*exp(5/4)*exp(-t/4)*sin(sqrt(15)*t/4 - 5*sqrt(15)/4)*Heaviside(t - 5)/15

# %%
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return 2*sqrt(15)*exp(5/4)*exp(-t/4)*sin(sqrt(15)*t/4 - 5*sqrt(15)/4)*
plt.plot(t,f(t),t,+t/4,t,-t/4)
#trus ntar pas plt.plot(t,x(t)) tambahin disampingnya t. +t/4 sama t,-t/4
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,20])
plt.ylim([-10,10])
plt.grid()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-184327770628> in <module>()
#       1 import numpy as np
# ----> 2 t = np.teta(0)
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
# --> 215                                      "{!r}".format(__name__, attr))
#     216
#     217         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'teta'

# %%
"""
Soal Latihan Halaman 29 No.4b
4. Diberikan sistem pegas-massa dengan model berikut
Selesaikan masalah nilai awal tersebut dengan transformasi Laplace untuk berbagai f(t)
berikut. Tentukan kurva amplopnya jika ada. Beri interpretasi.
"""

# a. 
# Mencari Solusi dari x'' + x = sin(2*t)*Heaviside(t) - sin(2t)*Heaviside(t-2*pi)
from sympy.integrals.transforms import laplace_transform
from sympy.integrals.transforms import inverse_laplace_transform
from sympy import *
from sympy.abc import t, x, s, X, f, F
x, f, X = symbols('x f X', cls = Function)
t = symbols('t', positive = True)
s = symbols('s', real = True)
f = sin(2*t) + DiracDelta(t-2*pi)
x0 = 0              # x(0) = 0
v0 = 0              # x'(0) = 0
#input hasil transformasi Laplace persamaan diferensial
eom = Eq((s**2*X(s)-s*x0-v0) + X(s), laplace_transform(f, t, s, noconds = True))
Xofs = solve(eom,X(s))
soln = inverse_laplace_transform(Xofs[0],s,t)
soln_simp = expand(soln)
soln_simp
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-13154b8a76b8> in <module>()
#      21 eom = Eq((s**2*X(s)-s*x0-v0) + X(s), laplace_transform(f, t, s, noconds = True))
#      22 Xofs = solve(eom,X(s))
# ---> 23 soln = inverse_laplace_transform(Xofs[0],s,t)
#      24 soln_simp = expand(soln)
#      25 soln_simp
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in inverse_laplace_transform(F, s, t, plane, **hints)
#    1290     if isinstance(F, MatrixBase) and hasattr(F, 'applyfunc'):
#    1291         return F.applyfunc(lambda Fij: inverse_laplace_transform(Fij, s, t, plane, **hints))
# -> 1292     return InverseLaplaceTransform(F, s, t, plane).doit(**hints)
#    1293
#    1294
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     119             try:
#     120                 return self._compute_transform(self.function,
# --> 121                     self.function_variable, self.transform_variable, **hints)
#     122             except IntegralTransformError:
#     123                 pass
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in _compute_transform(self, F, s, t, **hints)
#    1242
#    1243     def _compute_transform(self, F, s, t, **hints):
# -> 1244         return _inverse_laplace_transform(F, s, t, self.fundamental_plane, **hints)
#    1245
#    1246     def _as_integral(self, F, s, t):
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in wrapper(noconds, *args, **kwargs)
#     203         @wraps(func)
#     204         def wrapper(*args, noconds=default, **kwargs):
# --> 205             res = func(*args, **kwargs)
#     206             if noconds:
#     207                 return res[0]
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in _inverse_laplace_transform(F, s, t_, plane, simplify)
#    1212     #      exponentials up
#    1213
# -> 1214     return _simplify(f.subs(t, t_), simplify), cond
#    1215
#    1216
#
# /usr/local/lib/python3.7/dist-packages/sympy/integrals/transforms.py in _simplify(expr, doit)
#     179     from sympy import powdenest, piecewise_fold
#     180     if doit:
# --> 181         return simplify(powdenest(piecewise_fold(expr), polar=True))
#     182     return expr
#     183
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     663
#     664     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 665         expr = trigsimp(expr, deep=True)
#     666
#     667     if expr.has(log):
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in futrig(e, hyper, **kwargs)
#    1098
#    1099     old = e
# -> 1100     e = bottom_up(e, _futrig)
#    1101
#    1102     if hyper and e.has(HyperbolicFunction):
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1154     if args is not None:
#    1155         if args:
# -> 1156             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1157             if args != rv.args:
#    1158                 rv = rv.func(*args)
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1154     if args is not None:
#    1155         if args:
# -> 1156             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1157             if args != rv.args:
#    1158                 rv = rv.func(*args)
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1157             if args != rv.args:
#    1158                 rv = rv.func(*args)
# -> 1159             rv = F(rv)
#    1160         elif atoms:
#    1161             rv = F(rv)
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in _futrig(e)
#    1166             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1167         )]
# -> 1168     e = greedy(tree, objective=Lops)(e)
#    1169
#    1170     if coeff is not None:
#
# /usr/local/lib/python3.7/dist-packages/sympy/strategies/core.py in minrule(expr)
#     112
#     113     def minrule(expr):
# --> 114         return min([rule(expr) for rule in rules], key=objective)
#     115     return minrule
#
# /usr/local/lib/python3.7/dist-packages/sympy/strategies/core.py in <listcomp>(.0)
#     112
#     113     def minrule(expr):
# --> 114         return min([rule(expr) for rule in rules], key=objective)
#     115     return minrule
#
# /usr/local/lib/python3.7/dist-packages/sympy/strategies/core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1143         TR10,  # sin-cos of sums -> sin-cos prod
#    1144         TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
# -> 1145         lambda x: _eapply(factor, x, trigs),
#    1146         TR14,  # factored powers of identities
#    1147         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# /usr/local/lib/python3.7/dist-packages/sympy/simplify/trigsimp.py in _eapply(func, e, cond)
#    1191         return e
#    1192     if _is_Expr(e) or not e.args:
# -> 1193         return func(e)
#    1194     return e.func(*[
#    1195         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in factor(f, deep, *gens, **args)
#    6368
#    6369     try:
# -> 6370         return _generic_factor(f, gens, args, method='factor')
#    6371     except PolynomialError as msg:
#    6372         if not f.is_commutative:
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in _generic_factor(expr, gens, args, method)
#    6040     opt = options.build_options(gens, args)
#    6041     opt['fraction'] = fraction
# -> 6042     return _symbolic_factor(sympify(expr), opt, method)
#    6043
#    6044
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in _symbolic_factor(expr, opt, method)
#    5980         if hasattr(expr,'_eval_factor'):
#    5981             return expr._eval_factor()
# -> 5982         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    5983         return _keep_coeff(coeff, _factors_product(factors))
#    5984     elif hasattr(expr, 'args'):
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in _symbolic_factor_list(expr, opt, method)
#    5945             func = getattr(poly, method + '_list')
#    5946
# -> 5947             _coeff, _factors = func()
#    5948             if _coeff is not S.One:
#    5949                 if exp.is_Integer:
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in factor_list(f)
#    3314         if hasattr(f.rep, 'factor_list'):
#    3315             try:
# -> 3316                 coeff, factors = f.rep.factor_list()
#    3317             except DomainError:
#    3318                 return S.One, [(f, 1)]
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polyclasses.py in factor_list(f)
#     793     def factor_list(f):
#     794         """Returns a list of irreducible factors of ``f``. """
# --> 795         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     796         return coeff, [ (f.per(g), k) for g, k in factors ]
#     797
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1389         coeff, factors = dmp_ext_factor(f, u, K0)
#    1390     elif K0.is_GaussianRing:
# -> 1391         coeff, factors = dmp_zz_i_factor(f, u, K0)
#    1392     elif K0.is_GaussianField:
#    1393         coeff, factors = dmp_qq_i_factor(f, u, K0)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_zz_i_factor(f, u, K0)
#    1204     K1 = K0.get_field()
#    1205     f = dmp_convert(f, u, K0, K1)
# -> 1206     coeff, factors = dmp_qq_i_factor(f, u, K1)
#    1207
#    1208     new_factors = []
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_qq_i_factor(f, u, K0)
#    1193     K1 = K0.as_AlgebraicField()
#    1194     f = dmp_convert(f, u, K0, K1)
# -> 1195     coeff, factors = dmp_factor_list(f, u, K1)
#    1196     factors = [(dmp_convert(fac, u, K1, K0), i) for fac, i in factors]
#    1197     coeff = K0.convert(coeff, K1)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1387         coeff, factors = dmp_gf_factor(f, u, K0)
#    1388     elif K0.is_Algebraic:
# -> 1389         coeff, factors = dmp_ext_factor(f, u, K0)
#    1390     elif K0.is_GaussianRing:
#    1391         coeff, factors = dmp_zz_i_factor(f, u, K0)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_ext_factor(f, u, K)
#    1266     s, g, r = dmp_sqf_norm(f, u, K)
#    1267
# -> 1268     factors = dmp_factor_list_include(r, u, K.dom)
#    1269
#    1270     if len(factors) == 1:
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_factor_list_include(f, u, K)
#    1458         return dup_factor_list_include(f, K)
#    1459
# -> 1460     coeff, factors = dmp_factor_list(f, u, K)
#    1461
#    1462     if not factors:
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1409         if K.is_ZZ:
#    1410             levels, f, v = dmp_exclude(f, u, K)
# -> 1411             coeff, factors = dmp_zz_factor(f, v, K)
#    1412
#    1413             for i, (f, k) in enumerate(factors):
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/factortools.py in dmp_zz_factor(f, u, K)
#    1145
#    1146     if dmp_degree(g, u) > 0:
# -> 1147         g = dmp_sqf_part(g, u, K)
#    1148         H = dmp_zz_wang(g, u, K)
#    1149         factors = dmp_trial_division(f, H, u, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/sqfreetools.py in dmp_sqf_part(f, u, K)
#     254     gcd = f
#     255     for i in range(u+1):
# --> 256         gcd = dmp_gcd(gcd, dmp_diff_in(f, 1, i, u, K), u, K)
#     257     sqf = dmp_quo(f, gcd, u, K)
#     258
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_gcd(f, g, u, K)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#    1626
#    1627
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1582
#    1583     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1585
#    1586     return (dmp_inflate(h, J, u, K),
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1551         if K.is_ZZ and query('USE_HEU_GCD'):
#    1552             try:
# -> 1553                 return dmp_zz_heu_gcd(f, g, u, K)
#    1554             except HeuristicGCDFailed:
#    1555                 pass
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1332
#    1333         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1335
#    1336             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1307     """
#    1308     if not u:
# -> 1309         return dup_zz_heu_gcd(f, g, K)
#    1310
#    1311     result = _dmp_rr_trivial_gcd(f, g, u, K)
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/euclidtools.py in dup_zz_heu_gcd(f, g, K)
#    1205
#    1206         if ff and gg:
# -> 1207             h = K.gcd(ff, gg)
#    1208
#    1209             cff = ff // h
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/domains/pythonintegerring.py in gcd(self, a, b)
#      74     def gcd(self, a, b):
#      75         """Compute GCD of ``a`` and ``b``. """
# ---> 76         return python_gcd(a, b)
#      77
#      78     def lcm(self, a, b):
#
# KeyboardInterrupt:

# %%
"""
Soal Latihan Halaman 29 No.3.b
3. Tentukan solusi dari masalah nilai awal berikut dengan transformasi Laplace.
"""
# packages yang digunakan 
from sympy.integrals.transforms import laplace_transform
from sympy.integrals.transforms import inverse_laplace_transform
from sympy import *
from sympy.abc import t, x, s, X, f, F
y, f, Y = symbols('y f Y', cls = Function)
t = symbols('t', positive = True)
s = symbols('s', real = True)

"""
f = DiracDelta(t-2)
x0 = 4
v0 = 7
#input hasil transformasi Laplace persamaan diferensial
eom = Eq((s**2*X(s)-s*x0-v0)+10*(s*X(s)-x0)+21*X(s), laplace_transform(f, t, s, noconds = True))

Xofs = solve(eom,X(s))
soln = inverse_laplace_transform(Xofs[0],s,t)
soln_simp = expand(soln)
soln_simp
"""
f = Heaviside(t-pi)
y0 = 0
v0 = 0
#input hasil transformasi Laplace persamaan diferensial
eom = Eq((s**2*Y(s)-s*x0-v0) + 4*Y(s), laplace_transform(f, t, s, noconds = True))

Yofs = solve(eom,Y(s))
soln = inverse_laplace_transform(Yofs[0],s,t)
soln_simp = expand(soln)
soln_simp
# Out:
# -cos(2*t)*Heaviside(t - pi)/4 + Heaviside(t - pi)/4
