# %%
# packages yang digunakan  No 1.c
from sympy.integrals.transforms import laplace_transform
from sympy import symbols
from sympy import *
t = symbols('t', positive = True)
s = symbols('s', real = True)
k = symbols('k', real = True)
f = 1
i = 1
n = int(input("n= "))

#proses sigma
while i <= 2*n + 1:
    sum = Heaviside(t-i)*(-1)**i
    f = f + sum
    i = i + 1
print(laplace_transform(f,t,s))
# Out:
# n= 2
# ((exp(5*s) - exp(4*s) + exp(3*s) - exp(2*s) + exp(s) - 1)*exp(-5*s)/s, -oo, s > 0)

# %%
# Soal Latihan Nomor 2 Halaman 17
# mx'' + cx' + kx = F(t), x(0) = x_0, x'(0) = v_0
"""
Nomor 1
Untuk m = 1 c = 0, k = 4, x_0 = 0, dan v_0 = 0, sketsa solusi persamaan diferensial tersebut 
untuk berbagai parameter berikut. Berikan interpretasi.
a) F(t) = cos(t),
b) F(t) = cos(2t),
c) F(T) = cos(3t)

Penyelesaian: 
a) 
akan dicari solusi dari masalah nilai nilai awal
x'' + 4x = cos(t) , x(0) = 0 , x'(0) = 0
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + 4*x(t) - cos(t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 0)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return (np.cos(t)/3 - np.cos(2*t)/3)
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,20])
plt.ylim([-1,1])
plt.grid()
plt.show() 

"""
Penyelesaian: 
b) 
akan dicari solusi dari masalah nilai nilai awal
x'' + 4x = cos(2t) , x(0) = 0 , x'(0) = 0
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + 4*x(t) - cos(2*t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 0)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return ((t*np.sin(2*t))/4)
plt.plot(t,f(t),t,+t/4,t,-t/4)
#trus ntar pas plt.plot(t,x(t)) tambahin disampingnya t. +t/4 sama t,-t/4
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,20])
plt.ylim([-10,10])
plt.grid()
plt.show() 
"""
Penyelesaian: 
c) 
akan dicari solusi dari masalah nilai nilai awal
x'' + 4x = cos(3t) , x(0) = 0 , x'(0) = 0
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + 4*x(t) - cos(3*t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 0)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return ((np.cos(2*t)/5) - (np.cos(3*t)/5))
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,20])
plt.ylim([-1,1])
plt.grid()
plt.show()
# Out:
# Eq(x(t), cos(t)/3 - cos(2*t)/3)
# Eq(x(t), t*sin(2*t)/4)
# Eq(x(t), cos(2*t)/5 - cos(3*t)/5)

# %% [markdown]
# Pada persamaan Diferensial pertanyaan b, kurva solusinya mengalami resonansi.
# Sementara pada persamaan diferensial pertanyaan a dan c, kurva solusinya konstan (tidak mengalami resonansi)

# %%
# Soal Latihan Nomor 1 Halaman 17
# mx'' + cx' + kx = F(t), x(0) = x_0, x'(0) = v_0
"""
Nomor 1
Untuk m = 1 F(t) = 0, x_0 = 1, dan v_0 = 0, sketsa solusi persamaan diferensial tersebut 
untuk berbagai parameter berikut. Berikan interpretasi.
a) c = 4, k = 3,
b) c = 4, k = 4
c) c = 1, k = 3

Penyelesaian: 
a) 
akan dicari solusi dari masalah nilai nilai awal
x'' + 4x' + 3x = 0 , x(0) = 1 , x'(0) = 0
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + 4*Derivative(x(t), t) + 3*x(t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 1)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return (((3*np.exp(2*t) - 1)*np.exp((-3*t))/2))
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,6])
plt.ylim([-2,1.5])
plt.grid()
plt.show() 

"""
Penyelesaian: 
b) 
akan dicari solusi dari masalah nilai nilai awal
x'' + 4x' + 4x = 0 , x(0) = 1 , x'(0) = 0

"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + 4*Derivative(x(t), t) + 4*x(t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 1)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,20,1000)
def f(t) :
  return ((2*t + 1)*np.exp(-2*t))
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,6])
plt.ylim([-2,1.5])
plt.grid()
plt.show() 

"""
Penyelesaian: 
c) 
akan dicari solusi dari masalah nilai nilai awal
x'' + x' + 3x = 0 , x(0) = 1 , x'(0) = 0

"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + Derivative(x(t), t) + 3*x(t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 1)
cnd1 = Eq(sol.diff(t).subs(t,0), 0)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,30,1000)
def f(t) :
  return (((np.sqrt(11)*np.sin((np.sqrt(11)*t)/2)/11) + (np.cos((np.sqrt(11)*t)/2))*np.exp(-t/2)))
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,30])
plt.ylim([-2,2])
plt.grid()
plt.show()
# Out:
# Eq(x(t), (3*exp(2*t) - 1)*exp(-3*t)/2)
# Eq(x(t), (2*t + 1)*exp(-2*t))
# Eq(x(t), (sqrt(11)*sin(sqrt(11)*t/2)/11 + cos(sqrt(11)*t/2))*exp(-t/2))

# %%
""" 3. Persamaan Diferensial Biasa Orde n

Contoh:
akan dicari solusi dari masalah nilai nilai awal
  2x'' + 3x' + 9x = e^2t , x(0) =1 , x'(0) = 2
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(2*Derivative(x(t), t, t) + 3*Derivative(x(t), t) + 9*x(t) - pow(E, 2*t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 1)
cnd1 = Eq(sol.diff(t).subs(t,0), 2)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,5,100)
def f(t) :
  return (21*np.exp(t)**(3/4)*np.exp(2*t) + 242*np.sqrt(7)*np.sin(3*np.sqrt(7)*t/4) + 462*np.cos(3*np.sqrt(7)*t/4))/(483*np.exp(t)**(3/4))
plt.plot(t,f(t))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,5])
plt.ylim([0,10])
plt.grid()
plt.show() 

# Sistem Pegas-Massa Redaman 
""" 
Sistem pegas-massa redaman dapat dimodelkan dengan masalah nilai awal 
  mx'' + cx' + kx = F(t), x(0) = x_0, x'(0) = v_0
Contoh:
akan dicari solusi dari masalah nilai nilai awal
x'' + x = cos(t) , x(0) = 0 , x'(0) = 1
"""

# packages yang digunakan
from sympy import Function, dsolve, Derivative, solve, simplify, symbols, Eq, E, cos, sin
from sympy.abc import t
import numpy as np
from matplotlib import pyplot as plt
# penyelesaian
x = Function ('x')
sol = dsolve(Derivative(x(t), t, t) + x(t) - cos(t), x(t)).rhs
cnd0 = Eq(sol.subs(t, 0), 0)
cnd1 = Eq(sol.diff(t).subs(t,0), 1)

C1, C2 = symbols("C1, C2")
C1C2_sl = solve([cnd0, cnd1], (C1, C2))
sol1 = simplify(sol.subs(C1C2_sl))
print(Eq(x(t), sol1))
# Penggambaran Kurva Solusi 
t = np.linspace(0,30,100)
def f(t) :
  return (np.sin(t)*(1 + (t/2)))
plt.plot(t,f(t),t,+(1+(t/2)),t,-(1+(t/2)))
plt.xlabel('t')
plt.ylabel('x(t)')
plt.xlim([0,30])
plt.ylim([-20,20])
plt.grid()
plt.show()
# Out:
# Eq(x(t), (21*exp(11*t/4) + 242*sqrt(7)*sin(3*sqrt(7)*t/4) + 462*cos(3*sqrt(7)*t/4))*exp(-3*t/4)/483)
# Eq(x(t), (t/2 + 1)*sin(t))
