# %% [markdown]
# Nama: Carolina Sinaga
#
# ---
#
#
# NIM : 10119050
# Praktikum ke-8

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# SESI LATIHAN
# =========================

# %% [markdown]
# NOMOR 1

# %%
# b
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(0,100,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10

U = np.exp(-4*t*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t1,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
#c
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(0,100,250)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10

# t=1
t1 = np.linspace(0,1,250)
x,t1 = np.meshgrid(x,t1)
U1 = np.exp(-4*t1*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t1,U1, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()


fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(0,100,250)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10
# t=2
t2 = np.linspace(0,2,250)
x,t2 = np.meshgrid(x,t2)
U2 = np.exp(-4*t2*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t2,U2, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()



fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(0,100,250)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10
# t= 5
t3 = np.linspace(0,5,250)
x,t3 = np.meshgrid(x,t3)
U3 = np.exp(-4*t3*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t3,U3, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()



fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(0,100,250)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10
# t = 10
t4 = np.linspace(0,10,250)
x,t4 = np.meshgrid(x,t4)
U4 = np.exp(-4*t4*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t4,U4, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()



fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(0,100,250)

U = 0
u0 = np.cos(5*np.pi*x)
k = 0.05
L = 10
# t= 20
t5 = np.linspace(0,20,250)
x,t5 = np.meshgrid(x,t5)
U5 = np.exp(-4*t5*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t5,U5, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# SESI TES PRAKTIKUM
# ======================================

# %% [markdown]
# NOMOR 1

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import math

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(0,100,250)
t = np.linspace(0,500,250)
x,t = np.meshgrid(x,t)

U = 0
u0 = np.cos(5*np.pi*x)
k = 4*math.exp*math.exp/(math.pi + 2)
L = 2*math.pi

U = np.exp(-4*t*pow(np.pi,2)/25)*np.cos(5*np.pi*x)
surf=ax.plot_surface(x,t1,U, cmap=cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b7c915729d2d> in <module>()
#      15 U = 0
#      16 u0 = np.cos(5*np.pi*x)
# ---> 17 k = 4*math.exp*math.exp/(math.pi + 2)
#      18 L = 2*math.pi
#      19
#
# TypeError: unsupported operand type(s) for *: 'int' and 'builtin_function_or_method'

# %%
import math
math.exp
# Out:
# <function math.exp>
