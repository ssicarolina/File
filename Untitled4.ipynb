# %%
def f(p):  #fungsiyang ingin diintegralkan
  return p**2 
#input (" Nama Anda : ")
#input (" Nim Anda : ")
#input (" Fungsi : ")
import numpy as np
a=0 #batas bawah
b=1 #batas atas
print ("Batas Bawah :", a)
print ("Batas Atas :", b)
#print ("Grid", Grid)
Grid = np.array ([ 10, 50, 100, 200, 400, 800,1000,10000 ])
print("Grid = ",Grid)
print("Jumlah Grid\t|\tHasil")
d = len(Grid)
for i in range (d) :
  N = Grid[i]
  h=(b-a)/N #lebar grid
  jum=0.5*f(a)
  for j in range (1,N):
    pi=a+h*j
    jum=jum+f(pi)
  jum=jum+0.5*f(b)
  hasil=jum*h
  print(Grid[i],"\t\t\t",hasil)
# Out:
# Batas Bawah : 0
# Batas Atas : 1
# Grid =  [   10    50   100   200   400   800  1000 10000]
# Jumlah Grid	|	Hasil
# 10 			 0.3350000000000001
# 50 			 0.3334
# 100 			 0.33335000000000004
# 200 			 0.3333375000000001
# 400 			 0.333334375
# 800 			 0.3333335937500001
# 1000 			 0.33333349999999995
# 10000 			 0.33333333499999834

# %%
#Program Menghitung
#Spesifikasi : Membuat plot dari program menghitung integral dengan suatu batas tertentu menggunakan fungsi trapezoidal.
#Versi       : 1.0
#Last Edited : Minggu, 18 Oktober 2020
#Programer   : Sany Widiastuti

#Kamus
# N        : List
# a        : int
# b        : int
# y        : str

import matplotlib.pyplot as plt
import numpy as np

def f(x):  # Mendefinisikan Fungsi
    y = 3*x*x + 2 # Fungsi yang akan diintegralkan
    return y
a=0 # Batas bawah
b=5 # Batas atas
N=[1, 5, 10, 50, 100, 1000] # Jumlah grid yang akan dihitung

def tabel(g): # Mendefinisikan jumlah grid pada plot
    X=np.linspace(a,b,N[g]+1) # Grid yang akan di tampilkan
    Xd=np.linspace(a,b,N[g]) # Xd Array untuk membuat ploting dengan F(Xd)
    for i in range (N[g]):
        xs=[X[i],X[i],X[i+1],X[i+1]] # Garis yang sejajar dengan sumbu x
        ys=[0,f(X[i]),f(X[i+1]),0]# Garis yang sejajar dengan sumbu y
        plt.fill(xs,ys,'b',edgecolor='b',alpha=0.2) # Jumlah grid di tampilkan pada ploting
    return Xd

ax1 = plt.subplot(2, 3, 1)
plt.plot(tabel(0),f(tabel(0))) # Menampilkan Plot pada jumlah Grid=1
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[0]))

ax2 = plt.subplot(2, 3, 2)
plt.plot(tabel(1),f(tabel(1))) # Menampilkan Plot pada jumlah Grid=5
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[1]))

ax3 = plt.subplot(2, 3, 3)
plt.plot(tabel(2),f(tabel(2))) # Menampilkan Plot pada jumlah Grid=10
plt.xticks([0,1,2,3,4,5])
plt.title('\nTrapezoid Rule, N = {}'.format(N[2]))

ax4 = plt.subplot(2, 3, 4)
plt.plot(tabel(3),f(tabel(3))) # Menampilkan Plot pada jumlah Grid=50
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[3]))

ax5 = plt.subplot(2, 3, 5)
plt.plot(tabel(4),f(tabel(4))) # Menampilkan Plot pada jumlah Grid=100
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[4]))

ax6 = plt.subplot(2, 3, 6)
plt.plot(tabel(5),f(tabel(5))) # Menampilkan Plot pada jumlah Grid=100
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[5]))

plt.show()

# %%
print("Hello\nworld")
# Out:
# Hello
# world

# %%
#Program Menghitung
#Spesifikasi : Program menghitung integral dengan suatu batas tertentu menggunakan fungsi trapezoidal.
#Versi       : 1.0
#Last Edited : Minggu, 18 Oktober 2020
#Programer   : Sany Widiastuti

#Kamus
# nama     : str
# nim      : int
# grid     : int
# N        : List
# a        : int
# b        : int
# y        : str

#Algoritma
print(" Nama       : Sany Widiastuti")
print(" NIM        : 12319011 ")
print(" Fungsi     : f(x) = 3𝑥^2+2")
print(" Batas Bawah = 0")
print(" Batas Atas  = 5")
print(" Grid        = 1, 5, 10, 50, 100, 1000")

def f(x):  # Mendefinisikan Fungsi
    y = 3*x*x + 2 # Fungsi yang akan diintegralkan
    return y

def trapZ(a,b,N): # Mendefinisikan fungsi trapezoida
    h=(b-a)/N    # Lebar grid
    jum=0.5*f(a)
    for i in range(1,N):
        xi=a+h*i
        jum= jum+f(xi)
    jum= jum+0.5*f(b)
    hasil= jum*h
    return hasil

a=0 # Batas bawah
b=5 # Batas atas
N=[1, 5, 10, 50, 100, 1000] # Jumlah grid yang akan dihitung
print(" Jumlah Grid       |       Hasil   ")
for i in N:
    x=trapZ(a,b,i)
    print(i,'                   ',x)
# Out:
#  Nama       : Sany Widiastuti
#  NIM        : 12319011
#  Fungsi     : f(x) = 3𝑥^2+2
#  Batas Bawah = 0
#  Batas Atas  = 5
#  Grid        = 1, 5, 10, 50, 100, 1000
#  Jumlah Grid       |       Hasil
# 1                     197.5
# 5                     137.5
# 10                     135.625
# 50                     135.02500000000003
# 100                     135.00625
# 1000                     135.0000625

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):  # Mendefinisikan Fungsi
    y = 3*x*x + 2 # Fungsi yang akan diintegralkan
    return y
a=0 # Batas bawah
b=5 # Batas atas
N=[1, 5, 10, 50, 100, 1000] # Jumlah grid yang akan dihitung

def tabel(g): # Mendefinisikan jumlah grid pada plot
    X=np.linspace(a,b,N[g]+1) # Grid yang akan di tampilkan
    Xd=np.linspace(a,b,N[g]) # Xd Array untuk membuat ploting dengan F(Xd)
    for i in range (N[g]):
        xs=[X[i],X[i],X[i+1],X[i+1]] # Garis yang sejajar dengan sumbu x
        ys=[0,f(X[i]),f(X[i+1]),0]# Garis yang sejajar dengan sumbu y
        plt.fill(xs,ys,'b',edgecolor='b',alpha=0.2) # Jumlah grid di tampilkan pada ploting
    return Xd

# %%
#Program Menghitung
#Spesifikasi : Membuat plot dari program menghitung integral dengan suatu batas tertentu menggunakan fungsi trapezoidal.
#Versi       : 1.0
#Last Edited : Minggu, 18 Oktober 2020
#Programer   : Sany Widiastuti

#Kamus
# N        : List
# a        : int
# b        : int
# y        : str
import matplotlib.pyplot as plt
import numpy as np

def f(x):  # Mendefinisikan Fungsi
    y = 5*x**4 + 4*x**3 + 2*x + 3 # Fungsi yang akan diintegralkan
    return y
a=0 # Batas bawah
b=1 # Batas atas
N=[1, 5, 10, 50, 100, 1000] # Jumlah grid yang akan dihitung

def tabel(g): # Mendefinisikan jumlah grid pada plot
    X=np.linspace(a,b,N[g]+1) # Grid yang akan di tampilkan
    Xd=np.linspace(a,b,N[g]) # Xd Array untuk membuat ploting dengan F(Xd)
    for i in range (N[g]):
        xs=[X[i],X[i],X[i+1],X[i+1]] # Garis yang sejajar dengan sumbu x
        ys=[0,f(X[i]),f(X[i+1]),0]# Garis yang sejajar dengan sumbu y
        plt.fill(xs,ys,'r',edgecolor='c',alpha=0.9) # Jumlah grid di tampilkan pada ploting
    return Xd

ax1 = plt.subplot(2, 3, 1)
plt.plot(tabel(0),f(tabel(0))) # Menampilkan Plot pada jumlah Grid=1

ax2 = plt.subplot(2, 3, 2)
plt.plot(tabel(1),f(tabel(1))) # Menampilkan Plot pada jumlah Grid=5

ax3 = plt.subplot(2, 3, 3)
plt.plot(tabel(2),f(tabel(2))) # Menampilkan Plot pada jumlah Grid=10

ax4 = plt.subplot(2, 3, 4)
plt.plot(tabel(3),f(tabel(3))) # Menampilkan Plot pada jumlah Grid=50

ax5 = plt.subplot(2, 3, 5)
plt.plot(tabel(4),f(tabel(4))) # Menampilkan Plot pada jumlah Grid=100

ax6 = plt.subplot(2, 3, 6)
plt.plot(tabel(5),f(tabel(5))) # Menampilkan Plot pada jumlah Grid=100


plt.show()

# %%
# Program Menghitung
# Spesifikasi : Membuat plot dari program menghitung integral dengan suatu batas tertentu menggunakan fungsi trapezoidal.
# Versi       : 1.0
# Last Edited : Minggu, 18 Oktober 2020
# Programer   : Sany Widiastuti

# Kamus
# N        : List
# a        : int
# b        : int
# y        : str

import matplotlib.pyplot as plt
import numpy as np

def f(x):  # Mendefinisikan Fungsi
    y = (1 / (1 + x*x)) # Fungsi yang akan diintegralkan
    return y
a=0 # Batas bawah
b=5 # Batas atas
N=[1, 5, 10, 50, 100, 1000] # Jumlah grid yang akan dihitung

def tabel(g): # Mendefinisikan jumlah grid pada plot
    X=np.linspace(a,b,N[g]+1) # Grid yang akan di tampilkan
    Xd=np.linspace(a,b,N[g]) # Xd Array untuk membuat ploting dengan F(Xd)
    for i in range (N[g]):
        xs=[X[i],X[i],X[i+1],X[i+1]] # Garis yang sejajar dengan sumbu x
        ys=[0,f(X[i]),f(X[i+1]),0]# Garis yang sejajar dengan sumbu y
        plt.fill(xs,ys,'b',edgecolor='b',alpha=0.2) # Jumlah grid di tampilkan pada ploting
    return Xd

ax1 = plt.subplot(2, 3, 1)
plt.plot(tabel(0),f(tabel(0))) # Menampilkan Plot pada jumlah Grid=1
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[0]))
ax2 = plt.subplot(2, 3, 2)
plt.plot(tabel(1),f(tabel(1))) # Menampilkan Plot pada jumlah Grid=5
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[1]))
ax3 = plt.subplot(2, 3, 3)
plt.plot(tabel(2),f(tabel(2))) # Menampilkan Plot pada jumlah Grid=10
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[2]))
ax4 = plt.subplot(2, 3, 4)
plt.plot(tabel(3),f(tabel(3))) # Menampilkan Plot pada jumlah Grid=50
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[3]))
ax5 = plt.subplot(2, 3, 5)
plt.plot(tabel(4),f(tabel(4))) # Menampilkan Plot pada jumlah Grid=100
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[4]))
ax6 = plt.subplot(2, 3, 6)
plt.plot(tabel(5),f(tabel(5))) # Menampilkan Plot pada jumlah Grid=100
plt.xticks([0,1,2,3,4,5])
plt.title('Trapezoid Rule, N = {}'.format(N[5]))

plt.show()
