# %%
import numpy as np
import matplotlib.pyplot as plt

def fug (x,n) :
    return np.sin(n*x)/x
x = np.arange (-3*np.pi ,3*np.pi, 0.1)
max_m = 2
sumY = 0
m = 1
while m < max_m :
    n = 2*m-1
    sumY += fug(x,n)

y = 0.5 + 2*sumY/np.pi
plt.plot(x,y)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f6ae2d8c6cfb> in <module>()
#      10 while m < max_m :
#      11     n = 2*m-1
# ---> 12     sumY += fug(x,n)
#      13
#      14 y = 0.5 + 2*sumY/np.pi
#
# <ipython-input-1-f6ae2d8c6cfb> in fug(x, n)
#       3
#       4 def fug (x,n) :
# ----> 5     return np.sin(n*x)/x
#       6 x = np.arange (-3*np.pi ,3*np.pi, 0.1)
#       7 max_m = 2
#
# KeyboardInterrupt:
