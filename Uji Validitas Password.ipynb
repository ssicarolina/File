# %%
"""
Created on Tue Sep 29 15:30:08 2020

@author: Carolina
"""

# PROGRAM MENGUJI VALIDITAS PASSWORD
PASS = "Semangat" # Password yang benar

# Fungsi yang menguji password valid atau tidak
def Password(x): 
    if x==PASS:
        v= "Valid"
    else:
        v = "Tidak Valid"
    return(v)
a = True
while a==True:
    data = str(input("Masukkan password: "))
    b= Password(data)
    if len(data) !=8:
      print("Password Harus 8 karakter")
    else:
      if  b== "Valid":
        print("Selamat datang, Password Anda",Password(data))
        print(":)")
        a = False
      else :
          print("Password Tidak Valid")
          a= True
# Out:
# Masukkan password: Semangat
# Selamat datang, Password Anda Valid
# :)

# %%
if @a
